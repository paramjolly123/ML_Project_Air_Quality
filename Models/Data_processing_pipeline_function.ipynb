# %% [markdown]
# # EDA for Urban Air Pollution Challenge on Zindi
#
# S.M.O.G (Statistical Moddeling of Orbital Gases) 💨
#
# Problem: Ground-based air quality sensors are expensive and geographically sparse across Africa. This data gap hinders the real-time tracking of PM2.5​, a pollutant critical to public health and respiratory safety.
#
# Value of Product: Utilizing satellite imagery and weather data to estimate air quality provides a cost-effective alternative to physical hardware. It enables governments to issue health alerts and design urban policies based on localized pollution insights.
#
# Prediction: Daily PM2.5​ concentration levels.
#
# Evaluation Metric:
# RMSE (Primary): Penalizes large deviations. This is vital because under-predicting dangerous pollution spikes could lead to missed public health warnings.
# MAE (Secondary): Provides a baseline for average error and helps identify if the model is being skewed by outliers or extreme weather events.

# %% [markdown]
# # Importing Packages

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from function import *

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import RobustScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

import warnings
warnings.filterwarnings("ignore")

RSEED=42

# %% [markdown]
# # Importing the Data

# %%
# Import diabetes data
df = pd.read_csv('./../Data/Train.csv')
df.head()
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650    38.0        23.0        53.0  \
# 1  010Q650 X 2020-01-03  2020-01-03  010Q650    39.0        25.0        63.0
# 2  010Q650 X 2020-01-04  2020-01-04  010Q650    24.0         8.0        56.0
# 3  010Q650 X 2020-01-05  2020-01-05  010Q650    49.0        10.0        55.0
# 4  010Q650 X 2020-01-06  2020-01-06  010Q650    21.0         9.0        52.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere
# 0           769.50            92                             11.000000  \
# 1          1319.85            91                             14.600000
# 2          1181.96            96                             16.400000
# 3          1113.67            96                              6.911948
# 4          1164.82            95                             13.900001
#
#    relative_humidity_2m_above_ground  ...  L3_SO2_sensor_zenith_angle
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30557 entries, 0 to 30556
# Data columns (total 82 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Place_ID X Date                                      30557 non-null  object
#  1   Date                                                 30557 non-null  object
#  2   Place_ID                                             30557 non-null  object
#  3   target                                               30557 non-null  float64
#  4   target_min                                           30557 non-null  float64
#  5   target_max                                           30557 non-null  float64
#  6   target_variance                                      30557 non-null  float64
#  7   target_count                                         30557 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Place_ID X Date                     0
# Date                                0
# Place_ID                            0
# target                              0
# target_min                          0
#                                 ...
# L3_CH4_aerosol_optical_depth    24765
# L3_CH4_sensor_azimuth_angle     24765
# L3_CH4_sensor_zenith_angle      24765
# L3_CH4_solar_azimuth_angle      24765
# L3_CH4_solar_zenith_angle       24765
# Length: 82, dtype: int64

# %% [markdown]
# # EDA 1

# %% [markdown]
# Dropping the target variables we will not use to not leak data. Also drop the CH4 data since it is missing close to 80% of the data

# %%
cols_to_drop = ["Place_ID X ",
    "target_",
    "ch4"
]


df = drop_features(df, cols_to_drop)
df.head()
# Out:
# Dropped 12 columns. New shape: (30557, 70)
#          Date Place_ID  target  precipitable_water_entire_atmosphere
# 0  2020-01-02  010Q650    38.0                             11.000000  \
# 1  2020-01-03  010Q650    39.0                             14.600000
# 2  2020-01-04  010Q650    24.0                             16.400000
# 3  2020-01-05  010Q650    49.0                              6.911948
# 4  2020-01-06  010Q650    21.0                             13.900001
#
#    relative_humidity_2m_above_ground  specific_humidity_2m_above_ground
# 0                          60.200001                            0.00804  \
# 1                          48.799999                            0.00839
# 2                          33.400002                            0.00750
# 3                          21.300001                            0.00391
# 4                          44.700001                            0.00535
#
#    temperature_2m_above_ground  u_component_of_wind_10m_above_ground
# ...

# %% [markdown]
# ## Checking for entrys per Place_ID

# %%
df['Place_ID'].value_counts()
# Out:
# Place_ID
# 010Q650    94
# JSXAVKO    94
# I5RGE5G    94
# I6718VY    94
# I6VIR8R    94
#            ..
# LKE9VQB    41
# S91MBTB    29
# 6KAHP8X    12
# MJSB8K5     7
# 5IUK9TG     3
# Name: count, Length: 340, dtype: int64

# %%
df['Date'].value_counts().sort_index()
# Out:
# Date
# 2020-01-02    324
# 2020-01-03    327
# 2020-01-04    329
# 2020-01-05    331
# 2020-01-06    327
#              ...
# 2020-03-31    326
# 2020-04-01    328
# 2020-04-02    329
# 2020-04-03    330
# 2020-04-04    323
# Name: count, Length: 94, dtype: int64

# %% [markdown]
# # Splitting the dataset

# %%
y = df["target"] 
X = df.drop("target", axis=1)

# Split into Train, Val, and Test (60/20/20)
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.20, random_state=RSEED)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=RSEED)

# %% [markdown]
# ## Interpolating based on same Place_ID

# %%
X_train_clean, train_stats = impute_full_pipeline(X_train)

# Transform Val & Test using Train stats (Prevents Data Leakage)
X_val_clean, _ = impute_full_pipeline(X_val, fit_stats=train_stats)
X_test_clean, _ = impute_full_pipeline(X_test, fit_stats=train_stats)

# Step C: Recombine features and targets into final DataFrames
train_df = pd.concat([X_train_clean, y_train], axis=1)
val_df   = pd.concat([X_val_clean, y_val], axis=1)
test_df  = pd.concat([X_test_clean, y_test], axis=1)

# --- 4. VERIFICATION ---
print(f"Final Train Shape: {train_df.shape} | NaNs left: {train_df.isna().sum().sum()}")
print(f"Final Val Shape:   {val_df.shape}   | NaNs left: {val_df.isna().sum().sum()}")
print(f"Final Test Shape:  {test_df.shape}  | NaNs left: {test_df.isna().sum().sum()}")
# Out:
# Final Train Shape: (18333, 70) | NaNs left: 0
# Final Val Shape:   (6112, 70)   | NaNs left: 0
# Final Test Shape:  (6112, 70)  | NaNs left: 0

# %% [markdown]
# ### Checking if there are any more nan values

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18333 entries, 26358 to 18540
# Data columns (total 70 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 18333 non-null  object
#  1   Place_ID                                             18333 non-null  object
#  2   precipitable_water_entire_atmosphere                 18333 non-null  float64
#  3   relative_humidity_2m_above_ground                    18333 non-null  float64
#  4   specific_humidity_2m_above_ground                    18333 non-null  float64
#  5   temperature_2m_above_ground                          18333 non-null  float64
#  6   u_component_of_wind_10m_above_ground                 18333 non-null  float64
#  7   v_component_of_wind_10m_above_ground                 18333 non-null  float64
# ...

# %% [markdown]
# # Feature Engineering

# %%
def feature_engineering_columns_pipeline(df, cols_to_drop_2 = ['Place_ID X Date',
    "Date",
    "Place_ID",
    "L3_CLOUD_cloud_base_height",
    "L3_CLOUD_cloud_base_pressure"
    ]):
    df = relative_mean_angles(df)
    df = cloud_fraction_reduction(df)
    df = sensor_altitude_reduction(df)
    df = calculate_air_mass_factors(df)
    df = calculate_atmospheric_indices(df)

    df = drop_features(df, cols_to_drop_2)
    print('new shape', df.shape)
    return df

# %%
train_df = feature_engineering_columns_pipeline(train_df)
test_df = feature_engineering_columns_pipeline(test_df)
val_df = feature_engineering_columns_pipeline(val_df)
# Out:
# Reduced features. New columns added: ['L3_SO2_SO2_slant_column_number_density', 'L3_SO2_absorbing_aerosol_index', 'L3_SO2_cloud_fraction', 'target', 'relative_azimuth', 'relative_zenith']
# Dropped 4 columns. New shape: (18333, 39)
# new shape (18333, 39)
# Reduced features. New columns added: ['L3_SO2_SO2_slant_column_number_density', 'L3_SO2_absorbing_aerosol_index', 'L3_SO2_cloud_fraction', 'target', 'relative_azimuth', 'relative_zenith']
# Dropped 4 columns. New shape: (6112, 39)
# new shape (6112, 39)
# Reduced features. New columns added: ['L3_SO2_SO2_slant_column_number_density', 'L3_SO2_absorbing_aerosol_index', 'L3_SO2_cloud_fraction', 'target', 'relative_azimuth', 'relative_zenith']
# Dropped 4 columns. New shape: (6112, 39)
# new shape (6112, 39)

# %% [markdown]
# # Saving the cleaned data to use for modelling

# %%
train_df.to_csv('./../Data/preprocessed/Train_cleaned.csv', index=False)
test_df.to_csv('./../Data/preprocessed/Test_cleaned.csv', index=False)
val_df.to_csv('./../Data/preprocessed/Validation_cleaned.csv', index=False)
##

# %% [markdown]
# # Loading the split data for a model

# %%
train_df_cleaned = pd.read_csv('./../Data/preprocessed/Train_cleaned.csv')
test_df_cleaned = pd.read_csv('./../Data/preprocessed/Test_cleaned.csv')
val_df_cleaned = pd.read_csv('./../Data/preprocessed/Validation_cleaned.csv')

# %%
y_train = train_df_cleaned["target"] 
X_train = train_df_cleaned.drop("target", axis =1)

y_test = test_df_cleaned["target"] 
X_test = test_df_cleaned.drop("target", axis =1)

y_val = val_df_cleaned["target"] 
X_val = val_df_cleaned.drop("target", axis =1)

# %% [markdown]
# # Baseline Model

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred_train = lin_reg.predict(X_train)
y_pred_val = lin_reg.predict(X_val)

# %%
print(f"The RMSE for train is ", round(root_mean_squared_error(y_train, y_pred_train),3))
print(f"The RMSE for validation is ", round(root_mean_squared_error(y_val, y_pred_val),3))
print(f"The MAE for train is ", round(mean_absolute_error(y_train, y_pred_train),3))
print(f"The MAE for validation is ", round(mean_absolute_error(y_val, y_pred_val),3))
print(f"The R2 for train is ", round(r2_score(y_train, y_pred_train),3))
print(f"The R2 for validation is ", round(r2_score(y_val, y_pred_val),3))
# Out:
# The RMSE for train is  36.583
# The RMSE for validation is  352.237
# The MAE for train is  26.108
# The MAE for validation is  29.971
# The R2 for train is  0.397
# The R2 for validation is  -57.594

# %%
X_val
# Out:
#       precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground
# 0                                13.780000                          88.579999  \
# 1                                 5.550000                          88.490003
# 2                                14.206592                          55.700001
# 3                                11.455556                          85.455555
# 4                                11.300000                          77.000000
# ...                                    ...                                ...
# 6107                             11.300000                          28.900000
# 6108                             14.911948                          92.300003
# 6109                             11.400001                          36.000000
# 6110                             19.980001                          94.420004
# 6111                              9.954000                          72.709094
#
# ...
